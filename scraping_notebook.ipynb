# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import requests 
from bs4 import BeautifulSoup as soup

header = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:124.0) Gecko/20100101 Firefox/124.0'} 
url = 'https://www.presidency.ucsb.edu/documents/inaugural-address-54' 
raw = requests.get(url,headers=header)

# %% [markdown]
# # Getting The Dictionary Done

# %%
url = 'https://www.presidency.ucsb.edu/documents/app-categories/spoken-addresses-and-remarks/presidential/inaugural-addresses?items_per_page=60'
raw = requests.get(url,headers=header)

# %%
bsObj = soup(raw.content,'html.parser') # Parse the html
links = bsObj.find_all('div', class_="field-title") 
names = bsObj.find_all('div', class_="col-sm-4 margin-top")

# %%
president_names = [name.p.a.text for name in names]

speech_links = [title.find('a')['href'] for title in links]

data = {'Name': president_names,
        'Link': speech_links}

# Create DataFrame
df = pd.DataFrame(data)

df
# Out:
#                           Name  \
# 0   Donald J. Trump (2nd Term)
# 1         Joseph R. Biden, Jr.
# 2   Donald J. Trump (1st Term)
# 3                 Barack Obama
# 4                 Barack Obama
# 5               George W. Bush
# 6               George W. Bush
# 7           William J. Clinton
# 8           William J. Clinton
# 9                  George Bush
# 10               Ronald Reagan
# 11               Ronald Reagan
# 12                Jimmy Carter
# 13               Richard Nixon
# 14               Richard Nixon
# 15           Lyndon B. Johnson
# 16             John F. Kennedy
# 17        Dwight D. Eisenhower
# 18        Dwight D. Eisenhower
# 19              Harry S Truman
# 20       Franklin D. Roosevelt
# 21       Franklin D. Roosevelt
# 22       Franklin D. Roosevelt
# 23       Franklin D. Roosevelt
# 24              Herbert Hoover
# 25             Calvin Coolidge
# 26           Warren G. Harding
# 27              Woodrow Wilson
# 28              Woodrow Wilson
# 29         William Howard Taft
# 30          Theodore Roosevelt
# 31            William McKinley
# 32            William McKinley
# 33            Grover Cleveland
# 34           Benjamin Harrison
# 35            Grover Cleveland
# 36           Chester A. Arthur
# 37           James A. Garfield
# 38         Rutherford B. Hayes
# 39            Ulysses S. Grant
# 40            Ulysses S. Grant
# 41              Andrew Johnson
# 42             Abraham Lincoln
# 43             Abraham Lincoln
# 44              James Buchanan
# 45             Franklin Pierce
# 46              Zachary Taylor
# 47               James K. Polk
# 48                  John Tyler
# 49      William Henry Harrison
# 50            Martin van Buren
# 51              Andrew Jackson
# 52              Andrew Jackson
# 53           John Quincy Adams
# 54                James Monroe
# 55                James Monroe
# 56               James Madison
# 57               James Madison
# 58            Thomas Jefferson
# 59            Thomas Jefferson
#
#                                                  Link
# 0                     /documents/inaugural-address-54
# 1                     /documents/inaugural-address-53
# 2                     /documents/inaugural-address-14
# 3                     /documents/inaugural-address-15
# 4                      /documents/inaugural-address-5
# 5                     /documents/inaugural-address-13
# 6                     /documents/inaugural-address-52
# 7                     /documents/inaugural-address-12
# 8                     /documents/inaugural-address-51
# 9                        /documents/inaugural-address
# 10                    /documents/inaugural-address-10
# 11                    /documents/inaugural-address-11
# 12                     /documents/inaugural-address-0
# 13  /documents/oath-office-and-second-inaugural-ad...
# 14                     /documents/inaugural-address-1
# 15        /documents/the-presidents-inaugural-address
# 16                     /documents/inaugural-address-2
# 17                /documents/second-inaugural-address
# 18                     /documents/inaugural-address-3
# 19                     /documents/inaugural-address-4
# 20                     /documents/inaugural-address-6
# 21                 /documents/third-inaugural-address
# 22                     /documents/inaugural-address-7
# 23                     /documents/inaugural-address-8
# 24                     /documents/inaugural-address-9
# 25                    /documents/inaugural-address-50
# 26                    /documents/inaugural-address-49
# 27                    /documents/inaugural-address-48
# 28                    /documents/inaugural-address-47
# 29                    /documents/inaugural-address-46
# 30                    /documents/inaugural-address-45
# 31                    /documents/inaugural-address-44
# 32                    /documents/inaugural-address-43
# 33                    /documents/inaugural-address-42
# 34                    /documents/inaugural-address-41
# 35                    /documents/inaugural-address-40
# 36  /documents/address-upon-assuming-the-office-pr...
# 37                    /documents/inaugural-address-39
# 38                    /documents/inaugural-address-38
# 39                    /documents/inaugural-address-37
# 40                    /documents/inaugural-address-36
# 41  /documents/address-upon-assuming-the-office-pr...
# 42                    /documents/inaugural-address-35
# 43                    /documents/inaugural-address-34
# 44                    /documents/inaugural-address-33
# 45                    /documents/inaugural-address-32
# 46                    /documents/inaugural-address-31
# 47                    /documents/inaugural-address-30
# 48  /documents/address-upon-assuming-the-office-pr...
# 49                    /documents/inaugural-address-29
# 50                    /documents/inaugural-address-28
# 51                    /documents/inaugural-address-27
# 52                    /documents/inaugural-address-26
# 53                    /documents/inaugural-address-25
# 54                    /documents/inaugural-address-24
# 55                    /documents/inaugural-address-23
# 56                    /documents/inaugural-address-22
# 57                    /documents/inaugural-address-21
# 58                    /documents/inaugural-address-20
# 59                    /documents/inaugural-address-19

# %% [markdown]
# # Each President Speech

# %%
bsObj = soup(raw.content,'html.parser') # Parse the html
speech = bsObj.find_all(class_="field-docs-content") # Find all listings of the kind we want

# %%
#print(speech)
